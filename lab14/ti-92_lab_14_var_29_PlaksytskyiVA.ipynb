# %% [markdown]
# <div align = "center">
#     Міністерство освіти і науки України<br>
#     Національний технічний університет України<br>
#     Київський політехнічний інститут ім. Ігоря Сікорського<br>
#     Телпоенергетичний факультет<br>
#     Кафедра АПЕПС<br><br><br><br><br>
#     Лабораторна робота №14<br>
#     Варіант №29<br><br><br><br><br><br>
# <div align= "right">
#     Виконав:<br>
#     студент групи ТІ-92<br>
#     Плаксицький В. А.<br>
#     Перевірив:<br>
#     Сігайов А. О.<br>
# <div align = "center">
#     Київ 2021

# %% [markdown]
# ## Варіант №29
#
# ### Завдання 404
#
# Даны натуральные числа $i$, $j$, действительная матрица размера 18 x 24
# (1 $\le$ $i$ $\lt$ $j$ $\le$ 24). Поменять в матрице местами $i$-й и $j$-й столбцы.

# %%
import random


def swap(matrix, col1, col2):
    """
    Swaps the specified columns of the matrix
    """
    for e in matrix:
        e[col1], e[col2] = e[col2], e[col1]



try:
    a = [[random.randint(-10, 10) for _ in range(24)] for _ in range(18)]
    print(*a, sep="\n")
    print("\n")
    i = int(input("Введіть i-й стовпець: "))
    j = int(input("Введіть j-й стовпець: "))
    if not (0 <= i <= 23 and 0 <= j <= 23 and i < j):
        raise ValueError
    swap(a, i, j)
    print(*a, sep="\n")
except ValueError:
    print("Неправильно введені дані")
    exit(1)
# Out:
# [-1, -10, -6, -1, -3, 0, -3, 4, -7, 3, 9, 3, 0, -2, -10, 0, 0, 4, -5, -7, -3, 5, 10, -2]
# [-5, 5, -4, 1, 2, 8, -9, -9, -10, -8, -1, 3, -2, 2, 5, 2, -9, 7, 0, -10, 0, 9, -9, -3]
# [-9, -2, 6, 9, -5, -3, -9, -3, 8, -8, -7, 5, 8, -5, 10, -9, -2, 8, 4, -1, 6, -1, 8, 1]
# [1, 4, -2, -3, 9, -10, -7, -9, -5, -10, -3, 6, -8, -6, -1, -3, 7, -4, 5, -4, 1, 7, 3, 0]
# [-1, 5, 0, -2, -1, -7, -5, 5, 9, 8, 3, 2, 2, 0, -3, -9, -3, -8, -7, -6, 6, 10, 2, -7]
# [5, 3, -4, -2, 4, -5, 0, 3, 10, 2, 1, -4, -2, -2, -6, -5, 10, 10, 2, -10, -2, 6, 0, 3]
# [8, -9, -8, -10, 3, -4, -8, -5, 4, 10, -2, -8, 9, 10, 4, -1, 7, 2, -6, 7, -3, -4, -5, -10]
# [-10, 7, 7, 4, 4, -10, 0, 7, -2, -1, 2, 5, -10, 8, -5, -2, -7, 1, 6, -2, -6, 6, 7, -8]
# [5, -1, 3, -5, -3, 5, -7, 5, 4, -8, 4, -6, 10, -9, 8, -8, 6, 10, -9, -5, -2, 3, -8, 5]
# [0, 2, 10, 2, 4, 5, 0, -5, -5, -3, -1, 10, -10, -3, -1, 10, -1, -1, 4, 10, 4, 6, -10, -6]
# [2, 9, 7, -7, -10, -1, -7, 3, 9, 3, -4, 6, -1, -4, 4, -8, 6, -3, -1, -2, 5, -10, -5, -9]
# ...
