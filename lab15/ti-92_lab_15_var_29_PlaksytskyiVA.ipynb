# %% [markdown]
# <div align = "center">
#     Міністерство освіти і науки України<br>
#     Національний технічний університет України<br>
#     Київський політехнічний інститут ім. Ігоря Сікорського<br>
#     Телпоенергетичний факультет<br>
#     Кафедра АПЕПС<br><br><br><br><br>
#     Лабораторна робота №15<br>
#     Варіант №29<br><br><br><br><br><br>
# <div align= "right">
#     Виконав:<br>
#     студент групи ТІ-92<br>
#     Плаксицький В. А.<br>
#     Перевірив:<br>
#     Сігайов А. О.<br>
# <div align = "center">
#     Київ 2021

# %% [markdown]
# ## Варіант №29
#
# ### Завдання 388
#
# В данной квадратной целочисленной матрице порядка 17 указать индексы всех элементов с наибольшим
# значением

# %%
import random
import itertools as it

a = [[random.randint(-10, 10) for _ in range(17)] for _ in range(17)]
print(*a, sep='\n')
maxValue = max(max(e for e in r) for r in a)
print()
print(*list(it.chain.from_iterable([[(i, j) for j in range(len(a)) if a[i][j] == maxValue] for i in range(len(a))])), sep='\n')
# Out:
# [-9, 2, -3, -5, 7, 7, 5, 5, -4, -10, 2, -5, -7, 9, -10, -5, -9]
# [-10, 4, -8, -6, 2, 9, 2, -2, 6, 3, -1, 10, -8, 9, 5, 10, -8]
# [7, 5, -4, 2, 9, 6, 8, -1, 0, -10, 6, 1, 10, 1, 3, 2, 4]
# [-1, 1, 0, 0, -9, 6, -10, 2, 5, 10, 4, -8, -2, 0, -3, -1, -5]
# [10, -3, 4, -8, 7, 0, 7, 3, 2, -6, -10, 2, 3, -4, -9, -9, -4]
# [5, 2, 4, -4, -8, 6, 6, 5, 4, -2, 9, 6, 2, 2, 6, 3, 6]
# [2, 8, 0, -1, -1, 8, -2, -5, 3, 5, -5, 6, -10, -1, -7, -2, -5]
# [7, 8, 6, 7, 9, 9, 7, 7, -3, 8, 10, 1, -6, -5, 2, -5, -3]
# [2, -1, -10, 0, -3, 8, 5, -10, 0, 4, 7, -2, 8, 10, 0, 4, -10]
# [-10, -10, 2, 5, -7, -10, -8, -10, 0, -9, 3, 9, 8, 4, -5, 1, 1]
# [-1, 0, -7, -7, -5, 5, 6, 9, -10, 1, 1, -9, -9, -7, 4, 3, -9]
# [-6, -4, 10, -9, 9, -4, -5, 1, -6, 6, -10, 7, 1, -9, 1, 4, -8]
# [-8, -2, -1, 10, -2, 7, 2, -8, -9, 5, -3, 8, 6, -6, 0, -3, -5]
# [-2, -4, 4, 7, 4, -2, -2, -4, -2, 9, 0, -9, 8, 1, -6, 9, 4]
# [-4, -8, 8, -4, 4, 10, -3, 10, -7, -10, -9, -1, 0, 0, 5, -9, 2]
# [-9, -10, -6, 7, -5, -5, 10, -2, -9, -9, 3, 4, -5, 10, 4, -2, 5]
# [8, 6, -8, -6, -8, -7, -7, 10, -1, 10, 10, -8, 4, 3, 6, 10, -2]
#
# (1, 11)
# (1, 15)
# (2, 12)
# (3, 9)
# (4, 0)
# (7, 10)
# (8, 13)
# (11, 2)
# (12, 3)
# (14, 5)
# (14, 7)
# (15, 6)
# (15, 13)
# (16, 7)
# (16, 9)
# (16, 10)
# (16, 15)
