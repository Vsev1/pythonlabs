# %% [markdown]
# <div align = "center">
#     Міністерство освіти і науки України<br>
#     Національний технічний університет України<br>
#     Київський політехнічний інститут ім. Ігоря Сікорського<br>
#     Телпоенергетичний факультет<br>
#     Кафедра АПЕПС<br><br><br><br><br>
#     Лабораторна робота №8<br>
#     Варіант №29<br><br><br><br><br><br>
# <div align= "right">
#     Виконав:<br>
#     студент групи ТІ-92<br>
#     Плаксицький В. А.<br>
#     Перевірив:<br>
#     Сігайов А. О.<br>
# <div align = "center">
#     Київ 2021

# %% [markdown]
# ## Варіант №29
#
# ### Завдання 178a
#
# Даны натуральные числа $n$, $a_1$, ..., $a_n$. Определить количество членов $a_k$ последовательности $a_1$, ..., $a_n$:
# а) являющихся нечетными числами;

# %%
import random

n = int(input("Введіть n: "))
nums = [random.randint(1,10) for i in range(n)]
print(nums)
print(sum(i % 2 == 1 for i in nums))
# Out:
# [4, 2, 2, 10, 7, 10, 7, 9, 9, 3]
# 5
