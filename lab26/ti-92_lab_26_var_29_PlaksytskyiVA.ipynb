# %% [markdown]
# <div align = "center">
#     Міністерство освіти і науки України<br>
#     Національний технічний університет України<br>
#     Київський політехнічний інститут ім. Ігоря Сікорського<br>
#     Телпоенергетичний факультет<br>
#     Кафедра АПЕПС<br><br><br><br><br>
#     Лабораторна робота №26<br>
#     Варіант №29<br><br><br><br><br><br>
# <div align= "right">
#     Виконав:<br>
#     студент групи ТІ-92<br>
#     Плаксицький В. А.<br>
#     Перевірив:<br>
#     Сігайов А. О.<br>
# <div align = "center">
#     Київ 2021

# %% [markdown]
# ## Варіант №29
#
# ### Завдання 756
#
# Даны действительные числа $x$, $a$, $\varepsilon$ {$\varepsilon$ > 0, |$x$| < 1).
# Вычислить с точностью $\varepsilon$ значение $$1 + \sum_{
# \begin{subarray}{l} k = 1 \end{subarray}} \frac{a(a-1)...(a-k+1)}{k!} * x^{k}$$

# %%
import itertools
import math

x = float(input("Введіть x: "))
e = float(input("Введіть e: "))
a = int(input("Введіть a: "))
print(1 + sum(math.prod(a - k for k in range(k + 1)) / math.factorial(k) * x ** k for k in itertools.takewhile(
        lambda i: abs(math.prod(a - i for i in range(i + 1)) / math.factorial(i) * x ** i) >= e, itertools.count(0))))
# Out:
# 14.5
