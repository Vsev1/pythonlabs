# %% [markdown]
# <div align = "center">
#     Міністерство освіти і науки України<br>
#     Національний технічний університет України<br>
#     Київський політехнічний інститут ім. Ігоря Сікорського<br>
#     Телпоенергетичний факультет<br>
#     Кафедра АПЕПС<br><br><br><br><br>
#     Лабораторна робота №1<br>
#     Варіант №6<br><br><br><br><br><br>
# <div align= "right">
#     Виконав:<br>
#     студент групи ТІ-92<br>
#     Плаксицький В. А.<br>
#     Перевірив:<br>
#     Сігайов А. О.<br>
# <div align = "center">
#     Київ 2021

# %% [markdown]
# ## Варіант №6

# %% [markdown]
# ### Завдання 21
# Даны действительные числа $с$, $d$. Вычислить
# $|\frac{(\sin|cx_1^3 + dx_2^2-cd|)^3}{\sqrt{(cx_1^3 + dx_2^2-x_1)^2+3.14}}| + \tan(cx_1^3 + dx_2^2-x_1)$<br>
# где $x_1$ — больший, а $x_2$ — меньший корни уравнения $x^2 — Зx — |cd| = 0.$

# %%
import math

def f(c, d, x1, x2):
    result = abs((math.sin(abs(c * (x1 ** 3) + d * (x2 ** 2) - c * d))) ** 3
                 / math.sqrt((c * (x1 ** 3) + d * (x2 ** 2) - x1) ** 2 + 3.14)) \
             + math.tan(c * (x1 ** 3) + d * (x2 ** 2) - x1)
    print("Результат =",round(result, 3))


if __name__ == '__main__':
    print("Введіть значення змінних c та d: ")
    c = float(input("c = "))
    d = float(input("d = "))

    # x^2 - 3x - |cd| = 0
    discr = (-3) ** 2 - 4 * 1 * -(abs(c*d))
    print("Дискримінант =", discr)

    if discr > 0:
        x1 =  (3 + math.sqrt(discr)) / (2 * 1)
        x2 = (3 - math.sqrt(discr)) / (2 * 1)
        print("x1 =", x1,  "\nx2 =", x2)
        f(c, d, x1, x2)
    elif discr == 0:
        x1 = 3 / (2 * 1)
        x2 = 3 / (2 * 1)
        print("x1 =", x1,  "\nx2 =", x2)
        f(c, d, x1, x2)
    else:
        print("Коренів немає")
# Out:
# Введіть значення змінних c та d:
# Дискримінант = 33.0
# x1 = 4.372281323269014
# x2 = -1.3722813232690143
# Результат = -2.432

# %% [markdown]
# ### Завдання 27
# Даны действительные положительные числа $a$, $b$, $c$.
# По трем сторонам с длинами $a$, $b$, $c$ можно построить треугольник. Найти углы треугольника.

# %%
print("Введіть довжини сторін AB, BC та AC: ")
AB = float(input("AB = "))
BC = float(input("BC = "))
AC = float(input("AC = "))

A = math.degrees(math.acos((AB ** 2 + AC ** 2 - BC ** 2) / (2.0 * AB * AC)))
B = math.degrees(math.acos((AB ** 2 + BC ** 2 - AC ** 2) / (2.0 * AB * BC)))
C = math.degrees(math.acos((AC ** 2 + BC ** 2 - AB ** 2) / (2.0 * AC * BC)))

print("Кут А = ", round(A, 1))
print("Кут B = ", round(B, 1))
print("Кут C = ", round(C, 1))
# Out:
# Введіть довжини сторін AB, BC та AC:
# Кут А =  53.1
# Кут B =  36.9
# Кут C =  90.0

# %% [markdown]
# ### Завдання 32(г)
# Дано действительное число $a$. Не пользуясь никакими другими арифметическими операциями, кроме умшножения, получить:<br>
# г) $a^5$ и $a^{19}$ за пять операций;

# %%
a = int(input("Введіть значення: "))
a2 = a * a
a3 = a * a2
a5 = a3 * a2
print(a5)
a7 = a5 * a2
a7 *= a7
a19 = a5 * a7
print(a19)
# Out:
# 243
# 1162261467

# %% [markdown]
# ### Завдання 10
# Определить время падения камня на поверхность земли с высоты $h$

# %%
import math

h = float(input("Введіть висоту: "))
print("Результат =", round(math.sqrt(2 * h / 9.8), 3))
# Out:
# Результат = 0.904
