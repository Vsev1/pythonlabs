# %% [markdown]
# <div align = "center">
#     Міністерство освіти і науки України<br>
#     Національний технічний університет України<br>
#     Київський політехнічний інститут ім. Ігоря Сікорського<br>
#     Телпоенергетичний факультет<br>
#     Кафедра АПЕПС<br><br><br><br><br>
#     Лабораторна робота №2<br>
#     Варіант №6<br><br><br><br><br><br>
# <div align= "right">
#     Виконав:<br>
#     студент групи ТІ-92<br>
#     Плаксицький В. А.<br>
#     Перевірив:<br>
#     Сігайов А. О.<br>
# <div align = "center">
#     Київ 2021

# %% [markdown]
# ## Варіант №6
#
# ### Завдання 255
#
# Дана строка s.
# Получить первое натуральное $i$, для которого каждый из
# символов $s_i$ и $s_{i+i}$ совпадает с буквой $а$. Если такой пары
# символов в строке нет, то ответом должно быть число $0$.

# %%
print(input("Введіть строку: ").find("аа") + 1)
# Out:
# 6

# %% [markdown]
# ### Завдання 258
#
# Дана строка $s$.
# Удалить из данной строки все группы букв вида $abcd$.

# %%
print(input("Введіть строку: ").replace("abcd", ""))
# Out:
# kgb

# %% [markdown]
# ### Завдання 269
#
# Дана строка $s$.
# Группы символов, разделенные пробелами (одним или несколькими) и не содержащие пробелов внутри себя, будем
# называть $словами$.
# а) Подсчитать количество слов в данной строке.
# б) Подсчитать количество букв $а$ в последнем слове данной строки.
# в) Найти количество слов, начинающихся с буквы $б$.
# г) Найти количество слов, у которых первый и последний символы совпадают между собой.
# д) Найти какое-нибудь слово, начинающееся с буквы $а$.
# е) Преобразовать данную строку, заменяя всякое вхождение слова $это$ на слово $то$.
# ж) Найти длину самого короткого слова.

# %%
#1
s = input("Введіть строку: ").split()
print("Кількість слів: ", len(s))

#2
print("Кількість букв 'а' в останьому слові: ", s[len(s)-1].count("а"))

#3
print("Кількість слів, що починаються з літери 'б': ",
      len([i for i in s if i.startswith("б")]))

#4
print("Кількість слів, у яких перший і останній символи однакові: ",
      len([i[0] == i[-1] for i in s]))

#5
print("Слово, яке починається з літери 'а': ", [w for w in s if w[0] == 'а'][0])

#6
print(" ".join(s).replace("это", "то"))

#7
print(min(s, key=len))
# Out:
# Кількість слів:  4
# Кількість букв 'а' в останьому слові:  0
# Кількість слів, що починаються з літери 'б':  1
# Кількість слів, у яких перший і останній символи однакові:  4
# Слово, яке починається з літери 'а':  аба
# то аба впліи бщрс
# это

# %% [markdown]
# ### Завдання 252
#
# Дана строка $s$.
# Подсчитать:
# а) сколько раз среди данных символов встречается символ $+$ и сколько раз символ $*$;
# б) общее число вхождений символов $+$, $—$, $*$ в строку.

# %%
#1
s = input("Введіть строку: ")
print("Число символів '+': ", s.count("+"),
      "\nЧисло символів '*': ", s.count("*"))

#2
print("Загальне число символів '+', '—', '*' в строці: ",
      len([i for i in s if i in '+-*']))  #s.count('+') + s.count('-') + s.count('*')
