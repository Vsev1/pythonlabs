# %% [markdown]
# <div align = "center">
#     Міністерство освіти і науки України<br>
#     Національний технічний університет України<br>
#     Київський політехнічний інститут ім. Ігоря Сікорського<br>
#     Телпоенергетичний факультет<br>
#     Кафедра АПЕПС<br><br><br><br><br>
#     Лабораторна робота №3<br>
#     Варіант №6<br><br><br><br><br><br>
# <div align= "right">
#     Виконав:<br>
#     студент групи ТІ-92<br>
#     Плаксицький В. А.<br>
#     Перевірив:<br>
#     Сігайов А. О.<br>
# <div align = "center">
#     Київ 2021

# %% [markdown]
# ## Варіант №6
#
# ### Завдання 806
#
# Дан текст; выяснить, является ли этот текст:
# а) идентификатором;
# б) десятичной записью целого числа.

# %%
str = "1_b156"
print(str.isdecimal())
print(str.isidentifier())
# Out:
# False
# False
